# %%
import pandas as pd
df=pd.read_csv('data4.csv')
print(df)
# Out:
#     ROLL NO.  MARKS IN PERCENTAGE  DAYS PRESENT  Unnamed: 3  Unnamed: 4  \
# 0          1                   79           180         NaN         NaN
# 1          2                   73           160         NaN         NaN
# 2          3                   71           155         NaN         NaN
# 3          4                   71           156         NaN         NaN
# 4          5                   59           145         NaN         NaN
# 5          6                   30           122         NaN         NaN
# 6          7                   35           131         NaN         NaN
# 7          8                   44           156         NaN         NaN
# 8          9                   60           166         NaN         NaN
# 9         10                   60           170         NaN         NaN
# 10        11                   60           155         NaN         NaN
# 11        12                   63           158         NaN         NaN
# ...

# %%
df.corr(method="pearson")
# Out:
#                      ROLL NO.  MARKS IN PERCENTAGE  DAYS PRESENT  Unnamed: 3  \
# ROLL NO.             1.000000            -0.157312     -0.037812         NaN
# MARKS IN PERCENTAGE -0.157312             1.000000      0.863574         NaN
# DAYS PRESENT        -0.037812             0.863574      1.000000         NaN
# Unnamed: 3                NaN                  NaN           NaN         NaN
# Unnamed: 4                NaN                  NaN           NaN         NaN
# Unnamed: 5                NaN                  NaN           NaN         NaN
# Unnamed: 6                NaN                  NaN           NaN         NaN
#
#                      Unnamed: 4  Unnamed: 5  Unnamed: 6
# ROLL NO.                    NaN         NaN         NaN
# MARKS IN PERCENTAGE         NaN         NaN         NaN
# DAYS PRESENT                NaN         NaN         NaN
# Unnamed: 3                  NaN         NaN         NaN
# Unnamed: 4                  NaN         NaN         NaN
# ...
